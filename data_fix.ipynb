# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
dir = r'C:\Users\nkolev\Downloads\Si(001)-H-AsH3'

img_path = '\\20200217-105833_Hainault-Si(001)-H-AsH3--27_1_0_topright'

# %%
img = np.load(dir + img_path + '.npy')

# %%
mask = np.load(dir + img_path + '_mask_full.npy')

# %%
mask = cv2.resize(mask, (img.shape[1], img.shape[0]), interpolation = cv2.INTER_NEAREST)

# %%
mask.shape, img.shape
# Out:
# ((512, 512), (512, 512))

# %%
mask = mask[::-1,:]

# %%
n=50
m=200
plt.imshow(img[m:m+n,m:m+n])
plt.show()
plt.imshow(mask[m:m+n,m:m+n])
plt.show()  

plt.imshow(img)
plt.show()
plt.imshow(mask)
plt.show()

# %%
# save and overwrite the mask

np.save(dir + img_path + '_0_mask_full.npy', mask)
